# %% [markdown]
# # # Classifiers comparison: decision trees and k-nearest neighbors on the dataset Iris
#
#
# In the following program we compare the prediction results obtained by decision trees and k-nearest neighbors on the dataset Iris

# %% [markdown]
# The following cell shows the program training a decision tree and its results in preciction

# %%
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score # will be used to separate training and test
iris = load_iris()
clf = tree.DecisionTreeClassifier(criterion="entropy",random_state=300,min_samples_leaf=5,class_weight={0:1,1:1,2:1})
clf = clf.fit(iris.data, iris.target)
scores = cross_val_score(clf, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores)
# Out:
# [0.96666667 1.         0.86666667 0.86666667 1.        ]

# %% [markdown]
# The following cell shows the training of k-nearest neighbors and its prediction results.
# Here we use a uniform weighting setting (weights='uniform'): any neighbors weights the same in the majority voting aggregation.

# %%
from sklearn import neighbors
import pandas as pd
n_neighbors = 11
clf_knn = neighbors.KNeighborsClassifier(n_neighbors, weights='uniform')
clf_knn = clf_knn.fit(iris.data, iris.target)
scores = cross_val_score(clf_knn, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores)
# shows the model predictions with pandas
k_nn_results = []

for i in range(len(iris.target)):
    instance=(iris.data[i,:]).reshape(1, -1)
    predicted=clf_knn.predict(instance)[0]
    k_nn_results.append({
        'Instance': i,
        iris.feature_names[0]: iris.data[i,0],
        iris.feature_names[1]: iris.data[i,1],
        iris.feature_names[2]: iris.data[i,2],
        iris.feature_names[3]: iris.data[i,3],
        'Predicted class': iris.target_names[predicted],
        'True class': iris.target_names[iris.target[i]],
        'Correct': 'Yes' if predicted == iris.target[i] else 'No'
    })

results_df = pd.DataFrame(k_nn_results)
print(results_df.to_string(index=False, float_format='%.1f'))
# Out:
# [0.93333333 1.         1.         0.96666667 1.        ]
#  Instance  sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm) Predicted class True class Correct
#         0                5.1               3.5                1.4               0.2          setosa     setosa     Yes
#         1                4.9               3.0                1.4               0.2          setosa     setosa     Yes
#         2                4.7               3.2                1.3               0.2          setosa     setosa     Yes
#         3                4.6               3.1                1.5               0.2          setosa     setosa     Yes
#         4                5.0               3.6                1.4               0.2          setosa     setosa     Yes
#         5                5.4               3.9                1.7               0.4          setosa     setosa     Yes
#         6                4.6               3.4                1.4               0.3          setosa     setosa     Yes
#         7                5.0               3.4                1.5               0.2          setosa     setosa     Yes
#         8                4.4               2.9                1.4               0.2          setosa     setosa     Yes
#         9                4.9               3.1                1.5               0.1          setosa     setosa     Yes
#        10                5.4               3.7                1.5               0.2          setosa     setosa     Yes
#        11                4.8               3.4                1.6               0.2          setosa     setosa     Yes
#        12                4.8               3.0                1.4               0.1          setosa     setosa     Yes
#        13                4.3               3.0                1.1               0.1          setosa     setosa     Yes
#        14                5.8               4.0                1.2               0.2          setosa     setosa     Yes
#        15                5.7               4.4                1.5               0.4          setosa     setosa     Yes
#        16                5.4               3.9                1.3               0.4          setosa     setosa     Yes
#        17                5.1               3.5                1.4               0.3          setosa     setosa     Yes
#        18                5.7               3.8                1.7               0.3          setosa     setosa     Yes
#        19                5.1               3.8                1.5               0.3          setosa     setosa     Yes
#        20                5.4               3.4                1.7               0.2          setosa     setosa     Yes
#        21                5.1               3.7                1.5               0.4          setosa     setosa     Yes
#        22                4.6               3.6                1.0               0.2          setosa     setosa     Yes
#        23                5.1               3.3                1.7               0.5          setosa     setosa     Yes
#        24                4.8               3.4                1.9               0.2          setosa     setosa     Yes
#        25                5.0               3.0                1.6               0.2          setosa     setosa     Yes
#        26                5.0               3.4                1.6               0.4          setosa     setosa     Yes
#        27                5.2               3.5                1.5               0.2          setosa     setosa     Yes
#        28                5.2               3.4                1.4               0.2          setosa     setosa     Yes
#        29                4.7               3.2                1.6               0.2          setosa     setosa     Yes
#        30                4.8               3.1                1.6               0.2          setosa     setosa     Yes
#        31                5.4               3.4                1.5               0.4          setosa     setosa     Yes
#        32                5.2               4.1                1.5               0.1          setosa     setosa     Yes
#        33                5.5               4.2                1.4               0.2          setosa     setosa     Yes
#        34                4.9               3.1                1.5               0.2          setosa     setosa     Yes
#        35                5.0               3.2                1.2               0.2          setosa     setosa     Yes
#        36                5.5               3.5                1.3               0.2          setosa     setosa     Yes
#        37                4.9               3.6                1.4               0.1          setosa     setosa     Yes
#        38                4.4               3.0                1.3               0.2          setosa     setosa     Yes
#        39                5.1               3.4                1.5               0.2          setosa     setosa     Yes
#        40                5.0               3.5                1.3               0.3          setosa     setosa     Yes
#        41                4.5               2.3                1.3               0.3          setosa     setosa     Yes
#        42                4.4               3.2                1.3               0.2          setosa     setosa     Yes
#        43                5.0               3.5                1.6               0.6          setosa     setosa     Yes
#        44                5.1               3.8                1.9               0.4          setosa     setosa     Yes
#        45                4.8               3.0                1.4               0.3          setosa     setosa     Yes
#        46                5.1               3.8                1.6               0.2          setosa     setosa     Yes
#        47                4.6               3.2                1.4               0.2          setosa     setosa     Yes
#        48                5.3               3.7                1.5               0.2          setosa     setosa     Yes
#        49                5.0               3.3                1.4               0.2          setosa     setosa     Yes
#        50                7.0               3.2                4.7               1.4      versicolor versicolor     Yes
#        51                6.4               3.2                4.5               1.5      versicolor versicolor     Yes
#        52                6.9               3.1                4.9               1.5      versicolor versicolor     Yes
#        53                5.5               2.3                4.0               1.3      versicolor versicolor     Yes
#        54                6.5               2.8                4.6               1.5      versicolor versicolor     Yes
#        55                5.7               2.8                4.5               1.3      versicolor versicolor     Yes
#        56                6.3               3.3                4.7               1.6      versicolor versicolor     Yes
#        57                4.9               2.4                3.3               1.0      versicolor versicolor     Yes
#        58                6.6               2.9                4.6               1.3      versicolor versicolor     Yes
#        59                5.2               2.7                3.9               1.4      versicolor versicolor     Yes
#        60                5.0               2.0                3.5               1.0      versicolor versicolor     Yes
#        61                5.9               3.0                4.2               1.5      versicolor versicolor     Yes
#        62                6.0               2.2                4.0               1.0      versicolor versicolor     Yes
#        63                6.1               2.9                4.7               1.4      versicolor versicolor     Yes
#        64                5.6               2.9                3.6               1.3      versicolor versicolor     Yes
#        65                6.7               3.1                4.4               1.4      versicolor versicolor     Yes
#        66                5.6               3.0                4.5               1.5      versicolor versicolor     Yes
#        67                5.8               2.7                4.1               1.0      versicolor versicolor     Yes
#        68                6.2               2.2                4.5               1.5      versicolor versicolor     Yes
#        69                5.6               2.5                3.9               1.1      versicolor versicolor     Yes
#        70                5.9               3.2                4.8               1.8      versicolor versicolor     Yes
#        71                6.1               2.8                4.0               1.3      versicolor versicolor     Yes
#        72                6.3               2.5                4.9               1.5      versicolor versicolor     Yes
#        73                6.1               2.8                4.7               1.2      versicolor versicolor     Yes
#        74                6.4               2.9                4.3               1.3      versicolor versicolor     Yes
#        75                6.6               3.0                4.4               1.4      versicolor versicolor     Yes
#        76                6.8               2.8                4.8               1.4      versicolor versicolor     Yes
#        77                6.7               3.0                5.0               1.7       virginica versicolor      No
#        78                6.0               2.9                4.5               1.5      versicolor versicolor     Yes
#        79                5.7               2.6                3.5               1.0      versicolor versicolor     Yes
#        80                5.5               2.4                3.8               1.1      versicolor versicolor     Yes
#        81                5.5               2.4                3.7               1.0      versicolor versicolor     Yes
#        82                5.8               2.7                3.9               1.2      versicolor versicolor     Yes
#        83                6.0               2.7                5.1               1.6       virginica versicolor      No
#        84                5.4               3.0                4.5               1.5      versicolor versicolor     Yes
#        85                6.0               3.4                4.5               1.6      versicolor versicolor     Yes
#        86                6.7               3.1                4.7               1.5      versicolor versicolor     Yes
#        87                6.3               2.3                4.4               1.3      versicolor versicolor     Yes
#        88                5.6               3.0                4.1               1.3      versicolor versicolor     Yes
#        89                5.5               2.5                4.0               1.3      versicolor versicolor     Yes
#        90                5.5               2.6                4.4               1.2      versicolor versicolor     Yes
#        91                6.1               3.0                4.6               1.4      versicolor versicolor     Yes
#        92                5.8               2.6                4.0               1.2      versicolor versicolor     Yes
#        93                5.0               2.3                3.3               1.0      versicolor versicolor     Yes
#        94                5.6               2.7                4.2               1.3      versicolor versicolor     Yes
#        95                5.7               3.0                4.2               1.2      versicolor versicolor     Yes
#        96                5.7               2.9                4.2               1.3      versicolor versicolor     Yes
#        97                6.2               2.9                4.3               1.3      versicolor versicolor     Yes
#        98                5.1               2.5                3.0               1.1      versicolor versicolor     Yes
#        99                5.7               2.8                4.1               1.3      versicolor versicolor     Yes
#       100                6.3               3.3                6.0               2.5       virginica  virginica     Yes
#       101                5.8               2.7                5.1               1.9       virginica  virginica     Yes
#       102                7.1               3.0                5.9               2.1       virginica  virginica     Yes
#       103                6.3               2.9                5.6               1.8       virginica  virginica     Yes
#       104                6.5               3.0                5.8               2.2       virginica  virginica     Yes
#       105                7.6               3.0                6.6               2.1       virginica  virginica     Yes
#       106                4.9               2.5                4.5               1.7      versicolor  virginica      No
#       107                7.3               2.9                6.3               1.8       virginica  virginica     Yes
#       108                6.7               2.5                5.8               1.8       virginica  virginica     Yes
#       109                7.2               3.6                6.1               2.5       virginica  virginica     Yes
#       110                6.5               3.2                5.1               2.0       virginica  virginica     Yes
#       111                6.4               2.7                5.3               1.9       virginica  virginica     Yes
#       112                6.8               3.0                5.5               2.1       virginica  virginica     Yes
#       113                5.7               2.5                5.0               2.0       virginica  virginica     Yes
#       114                5.8               2.8                5.1               2.4       virginica  virginica     Yes
#       115                6.4               3.2                5.3               2.3       virginica  virginica     Yes
#       116                6.5               3.0                5.5               1.8       virginica  virginica     Yes
#       117                7.7               3.8                6.7               2.2       virginica  virginica     Yes
#       118                7.7               2.6                6.9               2.3       virginica  virginica     Yes
#       119                6.0               2.2                5.0               1.5       virginica  virginica     Yes
#       120                6.9               3.2                5.7               2.3       virginica  virginica     Yes
#       121                5.6               2.8                4.9               2.0       virginica  virginica     Yes
#       122                7.7               2.8                6.7               2.0       virginica  virginica     Yes
#       123                6.3               2.7                4.9               1.8       virginica  virginica     Yes
#       124                6.7               3.3                5.7               2.1       virginica  virginica     Yes
#       125                7.2               3.2                6.0               1.8       virginica  virginica     Yes
#       126                6.2               2.8                4.8               1.8       virginica  virginica     Yes
#       127                6.1               3.0                4.9               1.8       virginica  virginica     Yes
#       128                6.4               2.8                5.6               2.1       virginica  virginica     Yes
#       129                7.2               3.0                5.8               1.6       virginica  virginica     Yes
#       130                7.4               2.8                6.1               1.9       virginica  virginica     Yes
#       131                7.9               3.8                6.4               2.0       virginica  virginica     Yes
#       132                6.4               2.8                5.6               2.2       virginica  virginica     Yes
#       133                6.3               2.8                5.1               1.5       virginica  virginica     Yes
#       134                6.1               2.6                5.6               1.4       virginica  virginica     Yes
#       135                7.7               3.0                6.1               2.3       virginica  virginica     Yes
#       136                6.3               3.4                5.6               2.4       virginica  virginica     Yes
#       137                6.4               3.1                5.5               1.8       virginica  virginica     Yes
#       138                6.0               3.0                4.8               1.8      versicolor  virginica      No
#       139                6.9               3.1                5.4               2.1       virginica  virginica     Yes
#       140                6.7               3.1                5.6               2.4       virginica  virginica     Yes
#       141                6.9               3.1                5.1               2.3       virginica  virginica     Yes
#       142                5.8               2.7                5.1               1.9       virginica  virginica     Yes
#       143                6.8               3.2                5.9               2.3       virginica  virginica     Yes
#       144                6.7               3.3                5.7               2.5       virginica  virginica     Yes
#       145                6.7               3.0                5.2               2.3       virginica  virginica     Yes
#       146                6.3               2.5                5.0               1.9       virginica  virginica     Yes
#       147                6.5               3.0                5.2               2.0       virginica  virginica     Yes
#       148                6.2               3.4                5.4               2.3       virginica  virginica     Yes
#       149                5.9               3.0                5.1               1.8       virginica  virginica     Yes

# %% [markdown]
# In the following cell we use a varying weighting setting (weights='distance'): any neighbors weights inversely with its distance to the test instance in the majority voting aggregation.

# %%
n_neighbors = 11
clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
clf_knn2.fit(iris.data, iris.target)
scores2 = cross_val_score(clf_knn2, iris.data, iris.target, cv=5) # score will be the accuracy
print(scores2)

# shows the model predictions with pandas
k_nn2_results = []

for i in range(len(iris.target)):
    instance=(iris.data[i,:]).reshape(1, -1)
    predicted=clf_knn2.predict(instance)[0]
    k_nn2_results.append({
        'Instance': i,
        iris.feature_names[0]: iris.data[i,0],
        iris.feature_names[1]: iris.data[i,1],
        iris.feature_names[2]: iris.data[i,2],
        iris.feature_names[3]: iris.data[i,3],
        'Predicted class': iris.target_names[predicted],
        'True class': iris.target_names[iris.target[i]],
        'Correct': 'Yes' if predicted == iris.target[i] else 'No'
    })

results_df = pd.DataFrame(k_nn2_results)
print(results_df.to_string(index=False, float_format='%.1f'))
# Out:
# [0.96666667 1.         1.         0.96666667 1.        ]
#  Instance  sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm) Predicted class True class Correct
#         0                5.1               3.5                1.4               0.2          setosa     setosa     Yes
#         1                4.9               3.0                1.4               0.2          setosa     setosa     Yes
#         2                4.7               3.2                1.3               0.2          setosa     setosa     Yes
#         3                4.6               3.1                1.5               0.2          setosa     setosa     Yes
#         4                5.0               3.6                1.4               0.2          setosa     setosa     Yes
#         5                5.4               3.9                1.7               0.4          setosa     setosa     Yes
#         6                4.6               3.4                1.4               0.3          setosa     setosa     Yes
#         7                5.0               3.4                1.5               0.2          setosa     setosa     Yes
#         8                4.4               2.9                1.4               0.2          setosa     setosa     Yes
#         9                4.9               3.1                1.5               0.1          setosa     setosa     Yes
#        10                5.4               3.7                1.5               0.2          setosa     setosa     Yes
#        11                4.8               3.4                1.6               0.2          setosa     setosa     Yes
#        12                4.8               3.0                1.4               0.1          setosa     setosa     Yes
#        13                4.3               3.0                1.1               0.1          setosa     setosa     Yes
#        14                5.8               4.0                1.2               0.2          setosa     setosa     Yes
#        15                5.7               4.4                1.5               0.4          setosa     setosa     Yes
#        16                5.4               3.9                1.3               0.4          setosa     setosa     Yes
#        17                5.1               3.5                1.4               0.3          setosa     setosa     Yes
#        18                5.7               3.8                1.7               0.3          setosa     setosa     Yes
#        19                5.1               3.8                1.5               0.3          setosa     setosa     Yes
#        20                5.4               3.4                1.7               0.2          setosa     setosa     Yes
#        21                5.1               3.7                1.5               0.4          setosa     setosa     Yes
#        22                4.6               3.6                1.0               0.2          setosa     setosa     Yes
#        23                5.1               3.3                1.7               0.5          setosa     setosa     Yes
#        24                4.8               3.4                1.9               0.2          setosa     setosa     Yes
#        25                5.0               3.0                1.6               0.2          setosa     setosa     Yes
#        26                5.0               3.4                1.6               0.4          setosa     setosa     Yes
#        27                5.2               3.5                1.5               0.2          setosa     setosa     Yes
#        28                5.2               3.4                1.4               0.2          setosa     setosa     Yes
#        29                4.7               3.2                1.6               0.2          setosa     setosa     Yes
#        30                4.8               3.1                1.6               0.2          setosa     setosa     Yes
#        31                5.4               3.4                1.5               0.4          setosa     setosa     Yes
#        32                5.2               4.1                1.5               0.1          setosa     setosa     Yes
#        33                5.5               4.2                1.4               0.2          setosa     setosa     Yes
#        34                4.9               3.1                1.5               0.2          setosa     setosa     Yes
#        35                5.0               3.2                1.2               0.2          setosa     setosa     Yes
#        36                5.5               3.5                1.3               0.2          setosa     setosa     Yes
#        37                4.9               3.6                1.4               0.1          setosa     setosa     Yes
#        38                4.4               3.0                1.3               0.2          setosa     setosa     Yes
#        39                5.1               3.4                1.5               0.2          setosa     setosa     Yes
#        40                5.0               3.5                1.3               0.3          setosa     setosa     Yes
#        41                4.5               2.3                1.3               0.3          setosa     setosa     Yes
#        42                4.4               3.2                1.3               0.2          setosa     setosa     Yes
#        43                5.0               3.5                1.6               0.6          setosa     setosa     Yes
#        44                5.1               3.8                1.9               0.4          setosa     setosa     Yes
#        45                4.8               3.0                1.4               0.3          setosa     setosa     Yes
#        46                5.1               3.8                1.6               0.2          setosa     setosa     Yes
#        47                4.6               3.2                1.4               0.2          setosa     setosa     Yes
#        48                5.3               3.7                1.5               0.2          setosa     setosa     Yes
#        49                5.0               3.3                1.4               0.2          setosa     setosa     Yes
#        50                7.0               3.2                4.7               1.4      versicolor versicolor     Yes
#        51                6.4               3.2                4.5               1.5      versicolor versicolor     Yes
#        52                6.9               3.1                4.9               1.5      versicolor versicolor     Yes
#        53                5.5               2.3                4.0               1.3      versicolor versicolor     Yes
#        54                6.5               2.8                4.6               1.5      versicolor versicolor     Yes
#        55                5.7               2.8                4.5               1.3      versicolor versicolor     Yes
#        56                6.3               3.3                4.7               1.6      versicolor versicolor     Yes
#        57                4.9               2.4                3.3               1.0      versicolor versicolor     Yes
#        58                6.6               2.9                4.6               1.3      versicolor versicolor     Yes
#        59                5.2               2.7                3.9               1.4      versicolor versicolor     Yes
#        60                5.0               2.0                3.5               1.0      versicolor versicolor     Yes
#        61                5.9               3.0                4.2               1.5      versicolor versicolor     Yes
#        62                6.0               2.2                4.0               1.0      versicolor versicolor     Yes
#        63                6.1               2.9                4.7               1.4      versicolor versicolor     Yes
#        64                5.6               2.9                3.6               1.3      versicolor versicolor     Yes
#        65                6.7               3.1                4.4               1.4      versicolor versicolor     Yes
#        66                5.6               3.0                4.5               1.5      versicolor versicolor     Yes
#        67                5.8               2.7                4.1               1.0      versicolor versicolor     Yes
#        68                6.2               2.2                4.5               1.5      versicolor versicolor     Yes
#        69                5.6               2.5                3.9               1.1      versicolor versicolor     Yes
#        70                5.9               3.2                4.8               1.8      versicolor versicolor     Yes
#        71                6.1               2.8                4.0               1.3      versicolor versicolor     Yes
#        72                6.3               2.5                4.9               1.5      versicolor versicolor     Yes
#        73                6.1               2.8                4.7               1.2      versicolor versicolor     Yes
#        74                6.4               2.9                4.3               1.3      versicolor versicolor     Yes
#        75                6.6               3.0                4.4               1.4      versicolor versicolor     Yes
#        76                6.8               2.8                4.8               1.4      versicolor versicolor     Yes
#        77                6.7               3.0                5.0               1.7      versicolor versicolor     Yes
#        78                6.0               2.9                4.5               1.5      versicolor versicolor     Yes
#        79                5.7               2.6                3.5               1.0      versicolor versicolor     Yes
#        80                5.5               2.4                3.8               1.1      versicolor versicolor     Yes
#        81                5.5               2.4                3.7               1.0      versicolor versicolor     Yes
#        82                5.8               2.7                3.9               1.2      versicolor versicolor     Yes
#        83                6.0               2.7                5.1               1.6      versicolor versicolor     Yes
#        84                5.4               3.0                4.5               1.5      versicolor versicolor     Yes
#        85                6.0               3.4                4.5               1.6      versicolor versicolor     Yes
#        86                6.7               3.1                4.7               1.5      versicolor versicolor     Yes
#        87                6.3               2.3                4.4               1.3      versicolor versicolor     Yes
#        88                5.6               3.0                4.1               1.3      versicolor versicolor     Yes
#        89                5.5               2.5                4.0               1.3      versicolor versicolor     Yes
#        90                5.5               2.6                4.4               1.2      versicolor versicolor     Yes
#        91                6.1               3.0                4.6               1.4      versicolor versicolor     Yes
#        92                5.8               2.6                4.0               1.2      versicolor versicolor     Yes
#        93                5.0               2.3                3.3               1.0      versicolor versicolor     Yes
#        94                5.6               2.7                4.2               1.3      versicolor versicolor     Yes
#        95                5.7               3.0                4.2               1.2      versicolor versicolor     Yes
#        96                5.7               2.9                4.2               1.3      versicolor versicolor     Yes
#        97                6.2               2.9                4.3               1.3      versicolor versicolor     Yes
#        98                5.1               2.5                3.0               1.1      versicolor versicolor     Yes
#        99                5.7               2.8                4.1               1.3      versicolor versicolor     Yes
#       100                6.3               3.3                6.0               2.5       virginica  virginica     Yes
#       101                5.8               2.7                5.1               1.9       virginica  virginica     Yes
#       102                7.1               3.0                5.9               2.1       virginica  virginica     Yes
#       103                6.3               2.9                5.6               1.8       virginica  virginica     Yes
#       104                6.5               3.0                5.8               2.2       virginica  virginica     Yes
#       105                7.6               3.0                6.6               2.1       virginica  virginica     Yes
#       106                4.9               2.5                4.5               1.7       virginica  virginica     Yes
#       107                7.3               2.9                6.3               1.8       virginica  virginica     Yes
#       108                6.7               2.5                5.8               1.8       virginica  virginica     Yes
#       109                7.2               3.6                6.1               2.5       virginica  virginica     Yes
#       110                6.5               3.2                5.1               2.0       virginica  virginica     Yes
#       111                6.4               2.7                5.3               1.9       virginica  virginica     Yes
#       112                6.8               3.0                5.5               2.1       virginica  virginica     Yes
#       113                5.7               2.5                5.0               2.0       virginica  virginica     Yes
#       114                5.8               2.8                5.1               2.4       virginica  virginica     Yes
#       115                6.4               3.2                5.3               2.3       virginica  virginica     Yes
#       116                6.5               3.0                5.5               1.8       virginica  virginica     Yes
#       117                7.7               3.8                6.7               2.2       virginica  virginica     Yes
#       118                7.7               2.6                6.9               2.3       virginica  virginica     Yes
#       119                6.0               2.2                5.0               1.5       virginica  virginica     Yes
#       120                6.9               3.2                5.7               2.3       virginica  virginica     Yes
#       121                5.6               2.8                4.9               2.0       virginica  virginica     Yes
#       122                7.7               2.8                6.7               2.0       virginica  virginica     Yes
#       123                6.3               2.7                4.9               1.8       virginica  virginica     Yes
#       124                6.7               3.3                5.7               2.1       virginica  virginica     Yes
#       125                7.2               3.2                6.0               1.8       virginica  virginica     Yes
#       126                6.2               2.8                4.8               1.8       virginica  virginica     Yes
#       127                6.1               3.0                4.9               1.8       virginica  virginica     Yes
#       128                6.4               2.8                5.6               2.1       virginica  virginica     Yes
#       129                7.2               3.0                5.8               1.6       virginica  virginica     Yes
#       130                7.4               2.8                6.1               1.9       virginica  virginica     Yes
#       131                7.9               3.8                6.4               2.0       virginica  virginica     Yes
#       132                6.4               2.8                5.6               2.2       virginica  virginica     Yes
#       133                6.3               2.8                5.1               1.5       virginica  virginica     Yes
#       134                6.1               2.6                5.6               1.4       virginica  virginica     Yes
#       135                7.7               3.0                6.1               2.3       virginica  virginica     Yes
#       136                6.3               3.4                5.6               2.4       virginica  virginica     Yes
#       137                6.4               3.1                5.5               1.8       virginica  virginica     Yes
#       138                6.0               3.0                4.8               1.8       virginica  virginica     Yes
#       139                6.9               3.1                5.4               2.1       virginica  virginica     Yes
#       140                6.7               3.1                5.6               2.4       virginica  virginica     Yes
#       141                6.9               3.1                5.1               2.3       virginica  virginica     Yes
#       142                5.8               2.7                5.1               1.9       virginica  virginica     Yes
#       143                6.8               3.2                5.9               2.3       virginica  virginica     Yes
#       144                6.7               3.3                5.7               2.5       virginica  virginica     Yes
#       145                6.7               3.0                5.2               2.3       virginica  virginica     Yes
#       146                6.3               2.5                5.0               1.9       virginica  virginica     Yes
#       147                6.5               3.0                5.2               2.0       virginica  virginica     Yes
#       148                6.2               3.4                5.4               2.3       virginica  virginica     Yes
#       149                5.9               3.0                5.1               1.8       virginica  virginica     Yes

# %% [markdown]
# The following cell shows the tuning of the k-nn models with a varying value of k (number of nearest neighbors) and finds the best value of k (giving the maximum accuracy).

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

best_accuracy=0
best_k=1
A=np.zeros(len(y_train), dtype=np.float64) # for storing accuracies
for n_neighbors in np.arange(1,len(y_train)+1):
    clf_knn3 = neighbors.KNeighborsClassifier(n_neighbors, weights='distance')
    # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
    clf_knn3.fit(X_train, y_train)
    index=n_neighbors-1
    A[index]=clf_knn3.score(X_test, y_test)
    if best_accuracy<clf_knn3.score(X_test, y_test):
        best_accuracy=clf_knn3.score(X_test, y_test)
        best_k=n_neighbors
    #print("k neighbors="+str(n_neighbors))
    #print("accuracy="+str(clf_knn3.score(X_test, y_test)))

print("\n")
print("best k="+str(best_k))
print("best accuracy="+str(best_accuracy))

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

#plt.xticks(np.arange(1, len(y_train)+1, 8))
plt.yticks(np.arange(0.0,1.0,0.01))

plt.plot(np.arange(1,len(y_train)+1),A)

plt.show()
# Out:
# best k=7
# best accuracy=0.9666666666666667

# %% [markdown]
# In the following cell we plot in the same plot two subplots with the diagrams on accuracy with the two kinds of weighting
# of the vote of the neighbours (uniform and with distance)

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

i=0  #parameter in the control of the subplot to draw on'
f,(ax1, ax2) = plt.subplots(1, 2, sharey=True)
for weight_type in ['uniform','distance']:
    print("weighting:"+str(weight_type))
    A=np.zeros(len(y_train), dtype=np.float64) # for storing accuracies
    best_accuracy=0
    best_k=1
    for n_neighbors in np.arange(1,len(y_train)+1):
        clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights=weight_type)
        # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
        clf_knn2.fit(X_train, y_train)
        index=n_neighbors-1
        A[index]=clf_knn2.score(X_test, y_test)
        if best_accuracy<clf_knn2.score(X_test, y_test):
            best_accuracy=clf_knn2.score(X_test, y_test)
            best_k=n_neighbors
        #print("k neighbors="+str(n_neighbors))
        #print("accuracy="+str(clf_knn2.score(X_test, y_test)))

    print("\n")
    print("best k="+str(best_k))
    print("best accuracy="+str(best_accuracy))
    if i==0:
        ax1.plot(np.arange(1,len(y_train)+1),A)
        ax1.set_title('weighting type:'+str(weight_type))
    else:
        ax2.plot(np.arange(1,len(y_train)+1),A)
        ax2.set_title('weighting type:'+str(weight_type))
    i=i+1

plt.show()
# Out:
# weighting:uniform
#
#
# best k=7
# best accuracy=0.9666666666666667
# weighting:distance
#
#
# best k=7
# best accuracy=0.9666666666666667

# %% [markdown]
# In the following cell we plot (overlapping) in the same picture both the diagrams on accuracy with the two kinds of weighting
# of the vote of the neighbours (uniform and with distance)

# %%
import numpy as np
from numpy import zeros
from sklearn import neighbors
from sklearn.datasets import load_iris
iris = load_iris()
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.4, random_state=0)

fig = plt.figure()
fig.suptitle('Accuracy in k-nn with number of neighbors and types of weighting', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
ax.set_xlabel('n. neighbors')
ax.set_ylabel('accuracy')

A=np.zeros((len(y_train),2), dtype=np.float64) # 2 arrays for storing accuracies for each type of weigthing
i=0  #parameter in the control of the different diagram (=matrix A column index)
best_accuracy=0
for weight_type in ['uniform','distance']:
    print("\n weighting:"+str(weight_type))
    best_accuracy=0
    best_k=1
    for n_neighbors in np.arange(1,len(y_train)+1):
        clf_knn2 = neighbors.KNeighborsClassifier(n_neighbors, weights=weight_type)
        # (n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=1, **kwargs)
        clf_knn2.fit(X_train, y_train)
        index=n_neighbors-1 # computes the matrix row index
        A[index,i]=clf_knn2.score(X_test, y_test)
        if best_accuracy<clf_knn2.score(X_test, y_test):
            best_accuracy=clf_knn2.score(X_test, y_test)
            best_k=n_neighbors
        #print("k neighbors="+str(n_neighbors))
        #print("accuracy="+str(clf_knn2.score(X_test, y_test)))

    print("best k="+str(best_k))
    print("best accuracy="+str(best_accuracy))
    plt.plot(np.arange(1,len(y_train)+1),A[:,i])
    i=i+1
plt.legend(['uniform', 'distance'], loc='lower left')
plt.show()
# Out:
#  weighting:uniform
# best k=7
# best accuracy=0.9666666666666667
#
#  weighting:distance
# best k=7
# best accuracy=0.9666666666666667

# %% [markdown]
# Plot the Iris dataset, in 2-D, with a red color for Setosa, blu for Versicolor, Green for Virginica. Choose in a way decided by you, the best subset of 2 features to plot the Iris data so that the classes are separated the most.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# =========================
# 1) Carico il dataset Iris
# =========================
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# =========================
# 2) Scelgo le 2 feature migliori perchè massimizzano la separazione tra le classe
#    petal length (indice 2)
#    petal width  (indice 3)
# =========================
feat_x = 2  # petal length
feat_y = 3  # petal width

# =========================
# 3) Plot in 2D con colori richiesti
# =========================
plt.figure(figsize=(8, 6))

# Setosa → rosso
plt.scatter(
    X[y == 0, feat_x],
    X[y == 0, feat_y],
    c='red',
    label='Setosa',
    edgecolors='none'
)

# Versicolor → blu
plt.scatter(
    X[y == 1, feat_x],
    X[y == 1, feat_y],
    c='blue',
    label='Versicolor',
    edgecolors='none'
)

# Virginica → verde
plt.scatter(
    X[y == 2, feat_x],
    X[y == 2, feat_y],
    c='green',
    label='Virginica',
    edgecolors='none'
)

plt.xlabel(feature_names[feat_x])
plt.ylabel(feature_names[feat_y])
plt.title("Iris dataset in 2D (petal length vs petal width)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Plot the Iris dataset, in 2-D, with the color as above determined by the k-nn estimation

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier

# =========================
# 1) Carico il dataset Iris
# =========================
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
target_names = iris.target_names

# =========================
# 2) Scelgo le 2 feature migliori
#    petal length (2)
#    petal width  (3)
# =========================
feat_x = 2
feat_y = 3

X_2d = X[:, [feat_x, feat_y]]

# =========================
# 3) Addestro il k-NN in 2D
# =========================
k = 11
clf_knn = KNeighborsClassifier(
    n_neighbors=k,
    weights='distance'   # scelta migliore in generale
)
clf_knn.fit(X_2d, y)

# =========================
# 4) Predizione delle classi
# =========================
y_pred = clf_knn.predict(X_2d)

# =========================
# 5) Plot colorato secondo k-NN
# =========================
plt.figure(figsize=(8, 6))

# Setosa stimata → rosso
plt.scatter(
    X_2d[y_pred == 0, 0],
    X_2d[y_pred == 0, 1],
    c='red',
    label='Setosa (k-NN)',
    edgecolors='none'
)

# Versicolor stimata → blu
plt.scatter(
    X_2d[y_pred == 1, 0],
    X_2d[y_pred == 1, 1],
    c='blue',
    label='Versicolor (k-NN)',
    edgecolors='none'
)

# Virginica stimata → verde
plt.scatter(
    X_2d[y_pred == 2, 0],
    X_2d[y_pred == 2, 1],
    c='green',
    label='Virginica (k-NN)',
    edgecolors='none'
)

plt.xlabel(feature_names[feat_x])
plt.ylabel(feature_names[feat_y])
plt.title(f"Iris in 2D colorato secondo k-NN (k={k})")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# In the following, extend the above exercize on k-nn using metric learning.
# Use a kernel function for the distances computation.
# Use $K(x_t, x_n) = exp(-\gamma ||x_t-x_n||^2)$ were $\gamma$ is the inverse of the variance. Its best value is the purpose of this cell, and it will be determined by you according to the accuracy on Iris. If you want to convert a Gaussian kernel into a distance you can use one of these formulas below:
#
# 1.   $d(x_t,x_n)=\sqrt{-\frac{1}{\gamma}*ln(K(x_t,x_n))}$
# 2.   $d(x_t,x_n)=\sqrt{K(x_t,x_t)-2*K(x_t,x_n)+K(x_n,x_n)}$

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler


# =========================
# 1) Carico Iris
# =========================
iris = load_iris()
X = iris.data
y = iris.target

# Standardizzo perché sia KNN che kernel RBF sono molto sensibili alla scala
X = StandardScaler().fit_transform(X)


# =========================
# 2) Definisco kernel e distanza kernel-indotta (formula 2)
# =========================
def rbf_kernel(x, z, gamma: float):
    # K(x,z) = exp(-gamma * ||x-z||^2)
    diff = x - z
    return np.exp(-gamma * np.dot(diff, diff))

def kernel_distance_formula2(x, z, gamma: float):
    # d(x,z) = sqrt( K(x,x) - 2K(x,z) + K(z,z) )
    # Per RBF: K(x,x)=1 e K(z,z)=1 -> d = sqrt(2 - 2K(x,z))
    k_xz = rbf_kernel(x, z, gamma)
    return np.sqrt(2.0 - 2.0 * k_xz)


# =========================
# 3) Tuning di gamma con cross-validation
# =========================
# La consegna dice: gamma = inverso della varianza (come ordine di grandezza).
# Quindi prendo un gamma_base e ci costruisco una griglia logaritmica attorno.
gamma_base = 1.0 / np.var(X)   # varianza "globale" (dopo scaling sarà ~1, ma ok come base)
gamma_values = gamma_base * np.logspace(-2, 2, 25)  # 25 valori: da 1e-2*base a 1e2*base

n_neighbors = 11
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

best_gamma = None
best_acc = -1.0
accs = []

for gamma in gamma_values:
    fold_acc = []

    # Definisco una metrica "callable" con gamma fissato (closure)
    def metric_with_gamma(a, b, g=gamma):
        return kernel_distance_formula2(a, b, g)

    clf = KNeighborsClassifier(
        n_neighbors=n_neighbors,
        weights="distance",
        metric=metric_with_gamma
    )

    # Valuto manualmente la CV
    for train_idx, test_idx in cv.split(X, y):
        X_train, X_test = X[train_idx], X[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        clf.fit(X_train, y_train)
        fold_acc.append(clf.score(X_test, y_test))

    mean_acc = np.mean(fold_acc)
    accs.append(mean_acc)

    if mean_acc > best_acc:
        best_acc = mean_acc
        best_gamma = gamma

print(f"✅ Miglior gamma: {best_gamma:.6g}")
print(f"✅ Miglior accuracy media CV (5-fold): {best_acc:.4f}")


# =========================
# 4) Plot: accuracy vs gamma (scala log)
# =========================
plt.figure(figsize=(8, 5))
plt.plot(gamma_values, accs, marker="o")
plt.xscale("log")
plt.xlabel("gamma (scala log)")
plt.ylabel("Accuracy media (CV 5-fold)")
plt.title(f"Tuning gamma per KNN con distanza kernel-indotta (k={n_neighbors})")
plt.grid(True)
plt.show()


# =========================
# 5) Modello finale addestrato su tutto il dataset con il best gamma
# =========================
def best_metric(a, b, g=best_gamma):
    return kernel_distance_formula2(a, b, g)

clf_knn_kernel = KNeighborsClassifier(
    n_neighbors=n_neighbors,
    weights="distance",
    metric=best_metric
)

clf_knn_kernel.fit(X, y)

print("✅ Modello finale addestrato su tutto Iris con gamma ottimale.")
# Out:
# ✅ Miglior gamma: 0.01
# ✅ Miglior accuracy media CV (5-fold): 0.9667
# ✅ Modello finale addestrato su tutto Iris con gamma ottimale.
